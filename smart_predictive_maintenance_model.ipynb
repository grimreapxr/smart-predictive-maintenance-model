# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
num_features = 4  # Number of input features
model = Sequential([
    Dense(64, activation='relu', input_shape=(num_features,)),  # Input layer
    Dropout(0.2),  # Dropout for regularization
    Dense(32, activation='relu'),  # Hidden layer
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,433 (9.50 KB)
#  Trainable params: 2,433 (9.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Sensor	      Normal Range	Fault Range**
# **Temperature**	   30–60°C	      60–100°C
# **Vibration**	    0.2–0.7 g	       > 0.7 g
# **Current**	        8–12 A	   < 8 A or > 15 A
# **Voltage	**      220–240 V	   < 210 V or > 250 V
# **RPM**	         1450–1550	   < 1400 or > 1600

# %%
import numpy as np
import pandas as pd

n = 1000
fault_prob = 0.4  # 40% faulty records

# Normal Ranges
voltage = np.random.uniform(210, 230, n)
current = np.random.uniform(0.35, 0.65, n)
vibration = np.random.uniform(-0.5, 0.5, n)
rpm = np.random.uniform(2800, 3200, n)

# Fault Label
fault = np.random.choice([0, 1], size=n, p=[1 - fault_prob, fault_prob])

# Inject faults
for i in range(n):
    if fault[i] == 1:
        fault_type = np.random.choice(["voltage", "current", "vibration", "rpm"])
        if fault_type == "voltage":
            voltage[i] = np.random.choice([np.random.uniform(180, 209), np.random.uniform(241, 260)])
        elif fault_type == "current":
            current[i] = np.random.choice([np.random.uniform(0.1, 0.3), np.random.uniform(1.0, 1.5)])
        elif fault_type == "vibration":
            vibration[i] = np.random.choice([np.random.uniform(-1.0, -0.6), np.random.uniform(0.6, 1.0)])
        elif fault_type == "rpm":
            rpm[i] = np.random.choice([np.random.uniform(2400, 2700), np.random.uniform(3300, 3600)])

# Combine into DataFrame
data = pd.DataFrame({
    'Voltage (V)': voltage,
    'Current (A)': current,
    'Vibration (g)': vibration,
    'RPM': rpm,
    'Fault': fault
})

# Save to CSV
# data.to_csv("induction_motor_1000_data.csv", index=True)
print(data)
# Out:
#      Voltage (V)  Current (A)  Vibration (g)          RPM  Fault
# 0     227.897155     0.384271       0.944523  3001.761360      1
# 1     214.950761     0.208256       0.085388  2878.397181      1
# 2     220.142462     0.375494       0.343507  2943.378577      0
# 3     216.298951     0.592129       0.032239  2871.287967      0
# 4     217.816690     0.538084       0.733954  2830.674723      1
# ..           ...          ...            ...          ...    ...
# 995   243.269622     0.386331      -0.228678  3166.430914      1
# 996   211.706759     0.393600       0.288340  3077.839108      0
# 997   224.905537     0.494100       0.390701  2962.371587      0
# 998   245.527869     0.386957      -0.053268  3151.697260      1
# 999   225.619381     1.438819       0.250063  3096.917286      1
#
# [1000 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

x = data.drop("Fault", axis=1)
y = data["Fault"]


scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)


# Initialize a label encoder
encoder = LabelEncoder()

# Encode the labels
y_encoded = encoder.fit_transform(y)

# Split the dataset (80% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y_encoded, test_size=0.3, random_state=42)

# Further split training set into training and validation (80% train, 30% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# Print the shapes to verify
print(f"Train shape: {X_train.shape}, Validation shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (490, 4), Validation shape: (210, 4), Test shape: (300, 4)

# %%
import joblib

joblib.dump(scaler, 'motor_scaler.pkl')
# Out:
# ['motor_scaler.pkl']

# %%
# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=60,  # Number of training epochs
                    batch_size=32,  # Number of samples per training step
                    verbose=1)  # Show training progress
# Out:
# Epoch 1/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 0.4043 - loss: 0.6746 - val_accuracy: 0.3857 - val_loss: 0.6693
# Epoch 2/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4911 - loss: 0.6434 - val_accuracy: 0.4333 - val_loss: 0.6534
# Epoch 3/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5358 - loss: 0.6423 - val_accuracy: 0.5952 - val_loss: 0.6371
# Epoch 4/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6820 - loss: 0.6117 - val_accuracy: 0.6905 - val_loss: 0.6183
# Epoch 5/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6881 - loss: 0.6142 - val_accuracy: 0.8762 - val_loss: 0.5934
# Epoch 6/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7960 - loss: 0.5705 - val_accuracy: 0.9143 - val_loss: 0.5663
# Epoch 7/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8058 - loss: 0.5519 - val_accuracy: 0.9381 - val_loss: 0.5323
# Epoch 8/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8753 - loss: 0.5112 - val_accuracy: 0.9333 - val_loss: 0.4933
# Epoch 9/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8906 - loss: 0.4784 - val_accuracy: 0.9429 - val_loss: 0.4503
# Epoch 10/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8863 - loss: 0.4409 - val_accuracy: 0.9571 - val_loss: 0.4018
# Epoch 11/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9401 - loss: 0.3866 - val_accuracy: 0.9714 - val_loss: 0.3540
# Epoch 12/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9258 - loss: 0.3650 - val_accuracy: 0.9810 - val_loss: 0.3122
# Epoch 13/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9456 - loss: 0.3125 - val_accuracy: 0.9762 - val_loss: 0.2705
# Epoch 14/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8971 - loss: 0.3128 - val_accuracy: 0.9714 - val_loss: 0.2359
# Epoch 15/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9301 - loss: 0.2710 - val_accuracy: 0.9810 - val_loss: 0.2096
# Epoch 16/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9092 - loss: 0.2471 - val_accuracy: 0.9762 - val_loss: 0.1832
# Epoch 17/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9484 - loss: 0.2139 - val_accuracy: 0.9810 - val_loss: 0.1653
# Epoch 18/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9117 - loss: 0.2217 - val_accuracy: 0.9905 - val_loss: 0.1505
# Epoch 19/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9347 - loss: 0.2062 - val_accuracy: 0.9857 - val_loss: 0.1357
# Epoch 20/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9428 - loss: 0.1799 - val_accuracy: 0.9810 - val_loss: 0.1258
# Epoch 21/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9163 - loss: 0.1977 - val_accuracy: 1.0000 - val_loss: 0.1210
# Epoch 22/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9510 - loss: 0.1597 - val_accuracy: 0.9714 - val_loss: 0.1162
# Epoch 23/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9279 - loss: 0.1748 - val_accuracy: 0.9857 - val_loss: 0.1092
# Epoch 24/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9521 - loss: 0.1568 - val_accuracy: 0.9905 - val_loss: 0.1006
# Epoch 25/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9437 - loss: 0.1515 - val_accuracy: 0.9905 - val_loss: 0.0972
# Epoch 26/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9517 - loss: 0.1463 - val_accuracy: 0.9857 - val_loss: 0.0927
# Epoch 27/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9727 - loss: 0.1335 - val_accuracy: 0.9952 - val_loss: 0.0918
# Epoch 28/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9498 - loss: 0.1411 - val_accuracy: 0.9857 - val_loss: 0.0858
# Epoch 29/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9379 - loss: 0.1732 - val_accuracy: 0.9905 - val_loss: 0.0814
# Epoch 30/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9415 - loss: 0.1251 - val_accuracy: 0.9857 - val_loss: 0.0804
# Epoch 31/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9434 - loss: 0.1394 - val_accuracy: 0.9905 - val_loss: 0.0771
# Epoch 32/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9527 - loss: 0.1184 - val_accuracy: 0.9857 - val_loss: 0.0761
# Epoch 33/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9553 - loss: 0.1251 - val_accuracy: 0.9857 - val_loss: 0.0760
# Epoch 34/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9751 - loss: 0.0972 - val_accuracy: 0.9905 - val_loss: 0.0712
# Epoch 35/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9482 - loss: 0.1207 - val_accuracy: 0.9905 - val_loss: 0.0687
# Epoch 36/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9662 - loss: 0.1074 - val_accuracy: 0.9952 - val_loss: 0.0670
# Epoch 37/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9614 - loss: 0.1042 - val_accuracy: 0.9905 - val_loss: 0.0658
# Epoch 38/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9722 - loss: 0.0959 - val_accuracy: 0.9857 - val_loss: 0.0650
# Epoch 39/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9717 - loss: 0.0882 - val_accuracy: 0.9857 - val_loss: 0.0656
# Epoch 40/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9538 - loss: 0.1120 - val_accuracy: 0.9905 - val_loss: 0.0607
# Epoch 41/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9662 - loss: 0.0958 - val_accuracy: 0.9810 - val_loss: 0.0626
# Epoch 42/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9730 - loss: 0.0879 - val_accuracy: 0.9810 - val_loss: 0.0600
# Epoch 43/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9650 - loss: 0.1117 - val_accuracy: 0.9810 - val_loss: 0.0606
# Epoch 44/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9648 - loss: 0.0945 - val_accuracy: 0.9905 - val_loss: 0.0613
# Epoch 45/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9488 - loss: 0.1283 - val_accuracy: 0.9905 - val_loss: 0.0578
# Epoch 46/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9597 - loss: 0.1142 - val_accuracy: 0.9810 - val_loss: 0.0605
# Epoch 47/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9473 - loss: 0.0859 - val_accuracy: 0.9810 - val_loss: 0.0617
# Epoch 48/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9638 - loss: 0.1112 - val_accuracy: 0.9905 - val_loss: 0.0547
# Epoch 49/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9705 - loss: 0.0965 - val_accuracy: 0.9905 - val_loss: 0.0530
# Epoch 50/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9698 - loss: 0.1133 - val_accuracy: 0.9857 - val_loss: 0.0547
# Epoch 51/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9765 - loss: 0.0629 - val_accuracy: 0.9857 - val_loss: 0.0550
# Epoch 52/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9416 - loss: 0.1083 - val_accuracy: 0.9810 - val_loss: 0.0526
# Epoch 53/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9495 - loss: 0.1245 - val_accuracy: 0.9952 - val_loss: 0.0507
# Epoch 54/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9575 - loss: 0.1002 - val_accuracy: 0.9857 - val_loss: 0.0506
# Epoch 55/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9695 - loss: 0.0804 - val_accuracy: 0.9762 - val_loss: 0.0546
# Epoch 56/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9700 - loss: 0.0946 - val_accuracy: 0.9905 - val_loss: 0.0515
# Epoch 57/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9677 - loss: 0.0810 - val_accuracy: 0.9905 - val_loss: 0.0481
# Epoch 58/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9793 - loss: 0.0825 - val_accuracy: 0.9905 - val_loss: 0.0473
# Epoch 59/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9635 - loss: 0.1018 - val_accuracy: 0.9905 - val_loss: 0.0469
# Epoch 60/60
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9774 - loss: 0.0762 - val_accuracy: 0.9857 - val_loss: 0.0501

# %%
# Step 6: Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 96.67%

# %%
# Test input with actual sensor reading format:
# [Voltage (V), Current (A), Vibration (g), RPM]
test_input = [[220.0, 0.45, -0.35, 3060.0]]  # Real motor example

# Ensure the scaler matches the new feature layout
test_input_scaled = scaler.transform(test_input)

# Predict using your trained model
predicted_label = (model.predict(test_input_scaled) > 0.5).astype(int)

# Output result
if predicted_label[0][0] == 1:
    print("Result: Needs Maintenance")
else:
    print("Result: Normal")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Result: Normal

# %%
test_inputs = np.array([
    [220.0, 0.45, -0.35, 3060.0],  # Normal
    [205.0, 0.25, 0.65, 2700.0],   # Fault: low voltage, high vibration, low RPM
    [230.0, 0.60, 0.30, 3150.0],   # Normal
    [250.0, 1.20, 0.75, 3400.0],   # Fault: high voltage, high current, high RPM
    [210.0, 0.40, -0.20, 2900.0],  # Normal
    [198.0, 1.10, -0.60, 2680.0],  # Fault: low voltage, high current, low RPM
    [215.0, 0.50, -0.45, 3080.0],  # Normal
    [245.0, 1.25, 0.85, 3500.0],   # Fault: all abnormal
    [222.0, 0.38, -0.10, 3000.0],  # Normal
    [218.0, 0.90, 0.55, 3300.0],   # Fault: borderline high current & vibration
], dtype=np.float32)

# Apply the same scaler used during training
test_inputs_scaled = scaler.transform(test_inputs)

# Run predictions
predictions = (model.predict(test_inputs_scaled) > 0.5).astype(int)

# Display results
print("Test Results:\n")
for i, (input_data, prediction) in enumerate(zip(test_inputs, predictions)):
    label = "Needs Maintenance" if prediction[0] == 1 else "Normal"
    print(f"Sample {i+1}: {input_data} => Prediction: {label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Test Results:
#
# Sample 1: [ 2.20e+02  4.50e-01 -3.50e-01  3.06e+03] => Prediction: Normal
# Sample 2: [2.05e+02 2.50e-01 6.50e-01 2.70e+03] => Prediction: Needs Maintenance
# Sample 3: [2.30e+02 6.00e-01 3.00e-01 3.15e+03] => Prediction: Normal
# Sample 4: [2.5e+02 1.2e+00 7.5e-01 3.4e+03] => Prediction: Needs Maintenance
# Sample 5: [ 2.1e+02  4.0e-01 -2.0e-01  2.9e+03] => Prediction: Normal
# Sample 6: [ 1.98e+02  1.10e+00 -6.00e-01  2.68e+03] => Prediction: Needs Maintenance
# Sample 7: [ 2.15e+02  5.00e-01 -4.50e-01  3.08e+03] => Prediction: Normal
# Sample 8: [2.45e+02 1.25e+00 8.50e-01 3.50e+03] => Prediction: Needs Maintenance
# Sample 9: [ 2.22e+02  3.80e-01 -1.00e-01  3.00e+03] => Prediction: Normal
# Sample 10: [2.18e+02 9.00e-01 5.50e-01 3.30e+03] => Prediction: Needs Maintenance
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model.save("motor_model.h5")
print("Model saved as 'motor_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as 'motor_model.h5'

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model_reloaded = load_model("motor_model.h5")
print("Model loaded successfully")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully

# %%
test_input = [[50.0, 0.2, 10, 220, 1450]]
test_input_scaled = scaler.transform(test_input)

# Predict using the reloaded model
predicted_label = (model_reloaded.predict(test_input_scaled) > 0.5).astype(int)

if predicted_label[0][0] == 1:
    print("Result: Needs Maintenance")
else:
    print("Result: Normal")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Result: Normal
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

# 10 input samples: [Temperature, Vibration, Current, Voltage, RPM]
test_inputs = np.array([
    [40.0, 0.4, 10.0, 230.0, 1500.0],  # Normal
    [75.0, 1.2, 16.0, 210.0, 1350.0],  # Fault
    [45.0, 0.6, 11.0, 235.0, 1480.0],  # Normal
    [85.0, 0.5, 10.0, 250.0, 1500.0],  # Fault
    [38.0, 0.3, 9.0, 225.0, 1490.0],   # Normal
    [65.0, 0.8, 17.0, 240.0, 1450.0],  # Fault
    [42.0, 0.5, 10.0, 230.0, 1550.0],  # Normal
    [60.0, 1.1, 13.0, 260.0, 1600.0],  # Fault
    [30.0, 0.2, 8.0, 220.0, 1500.0],   # Normal
    [55.0, 1.3, 14.0, 215.0, 1390.0],  # Fault
])

# Scale the inputs using your original scaler
test_inputs_scaled = scaler.transform(test_inputs)

# Run predictions
predictions = (model.predict(test_inputs_scaled) > 0.5).astype(int)

# Print results
print("Results:\n")
for i, (raw_input, pred) in enumerate(zip(test_inputs, predictions)):
    status = "Needs Maintenance" if pred[0] == 1 else "Normal"
    print(f"Sample {i+1}: {raw_input} => Prediction: {status}")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1cc8650a2b99> in <cell line: 0>()
#      16
#      17 # Scale the inputs using your original scaler
# ---> 18 test_inputs_scaled = scaler.transform(test_inputs)
#      19
#      20 # Run predictions
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#    1060
#    1061         copy = copy if copy is not None else self.copy
# -> 1062         X = validate_data(
#    1063             self,
#    1064             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965         _check_n_features(_estimator, X, reset=reset)
#    2966
#    2967     return out
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _check_n_features(estimator, X, reset)
#    2827
#    2828     if n_features != estimator.n_features_in_:
# -> 2829         raise ValueError(
#    2830             f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831             f"is expecting {estimator.n_features_in_} features as input."
#
# ValueError: X has 5 features, but StandardScaler is expecting 4 features as input.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,499 (9.77 KB)
#  Trainable params: 2,497 (9.75 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
